# %% [markdown]
# <a href="https://www.kaggle.com/code/marcelargarcia/exerc1-etl?scriptVersionId=168762147" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spotify-data-from-pyspark-course/spotify-data.csv

# %%
df_spot = pd.read_csv('/kaggle/input/spotify-data-from-pyspark-course/spotify-data.csv')
df_spot
# Out:
#                             id                                           name  \
# 0       6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 1       6KuQTIu1KoTTkLXKrwlLPV       Fantasiestücke, Op. 111: Più tosto lento
# 2       6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3       6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 4       6N6tiFZ9vLTSOIxkj8qKrd    Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                        ...                                            ...
# 169904  4KppkflX7I3vJQk7urOJaS                  Skechers (feat. Tyga) - Remix
# 169905  1ehhGlTvjtHo2e4xJFB0SZ                 Sweeter (feat. Terrace Martin)
# 169906  52eycxprLhK3lPcRLbQiVk                               How Would I Know
# 169907  3wYOGJYD31sLRmBgCvWxa4                                    I Found You
# 169908  60RFlt48hm0l4Fu0JoccOl                          More Hearts Than Mine
#
# ...

# %% [markdown]
# ## The most popular songs in the last 10 years

# %%
current_year = pd.Timestamp.now().year

# %%
df_spot['year'] = pd.to_datetime(df_spot['year'], format='%Y')

# %%
last_10_years_df = df_spot[df_spot['year'].dt.year.between(current_year - 10, current_year)]
sorted_df = last_10_years_df.sort_values(by='popularity')

# %%
subset_df = sorted_df[['name', 'artists']].head(10)
subset_df
# Out:
#                                      name             artists
# 16199                     Sexy Movimiento  ['Wisin & Yandel']
# 16217   Lo Maan Liya (From "Raaz Reboot")    ['Arijit Singh']
# 16218                       Aye Dekhe Jaa    ['Arijit Singh']
# 169822                       Pobre Diabla        ['Don Omar']
# 169821             Hasta Que Salga El Sol        ['Don Omar']
# 16219                   Tomar Dyakha Naai    ['Arijit Singh']
# 169819                   Ojitos Chiquitos        ['Don Omar']
# 40204                Corazón En La Maleta      ['Luis Fonsi']
# 40203                Corazón En La Maleta      ['Luis Fonsi']
# 40206               No Me Doy Por Vencido      ['Luis Fonsi']

# %% [markdown]
# ## The number of songs released by artist and year of release

# %%
id_counts = df_spot.groupby(['artists', 'year'])['id'].count().reset_index()

# %%
id_counts = id_counts.rename(columns={'id': 'numb of songs'})
id_counts = id_counts.sort_values(by='numb of songs', ascending=False)
id_counts
# Out:
#                                                 artists       year  \
# 57228                             ['Эрих Мария Ремарк'] 1945-01-01
# 57232                              ['Эрнест Хемингуэй'] 1940-01-01
# 57231                              ['Эрнест Хемингуэй'] 1935-01-01
# 57227                             ['Эрих Мария Ремарк'] 1929-01-01
# 38318                            ['Orchestra Studio 7'] 1942-01-01
# ...                                                 ...        ...
# 23893  ['Jason Derulo', 'Nicki Minaj', 'Ty Dolla $ign'] 2017-01-01
# 23894                    ['Jason Derulo', 'Snoop Dogg'] 2013-01-01
# 23895                          ['Jason Derulo', 'Tyga'] 2013-01-01
# 23900                                  ['Jason Derulo'] 2016-01-01
# 57341                                            ['黑豹'] 1992-01-01
#
#        numb of songs
# 57228            536
# 57232            391
# 57231            277
# 57227            245
# 38318            238
# ...              ...
# ...

# %% [markdown]
# ## The artists with the highest average song popularity over the last 5 years.

# %%
last_5_years_df = df_spot[df_spot['year'].dt.year.between(current_year - 5, current_year)]

# %%
popularity_count = last_5_years_df.groupby(['artists'])['popularity'].sum().reset_index()

# %%
popularity_count = popularity_count.sort_values(by='popularity', ascending=False)
popularity_count
# Out:
#                                                 artists  popularity
# 1164                                   ['Lil Uzi Vert']        2777
# 2043                     ['YoungBoy Never Broke Again']        2563
# 1860                                     ['The Weeknd']        1790
# 1618                                       ['Rod Wave']        1674
# 1112                                       ['Lil Baby']        1605
# ...                                                 ...         ...
# 796   ['J Balvin', 'Yandel', 'Farruko', 'Nicky Jam',...           0
# 1222  ['Luis Fonsi', 'Aleks Syntek', 'Noel Schajris'...           0
# 794     ['J Balvin', 'Pharrell Williams', 'BIA', 'Sky']           0
# 77                     ['Alejandro Fernández', 'Morat']           0
# 1974        ['Wisin & Yandel', 'Chris Brown', 'T-Pain']           0
#
# [2119 rows x 2 columns]
